# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
df = pd.read_csv("mergedata2.csv")

# %%
df.head()
# Out:
#              County    State  Population  HouseholdIncome  TotalDebt  Multiple
# 0        Lee County  Alabama      156597            47564   136953.0  2.879342
# 1  Jefferson County  Alabama      659460            49321   115941.0  2.350743
# 2    Marengo County  Alabama       19743            32255    74335.0  2.304604
# 3    Russell County  Alabama       58480            38988    95871.0  2.458987
# 4  Covington County  Alabama       37519            39467   140630.0  3.563230

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite://', echo=False)

# %%
df.to_sql('merged_data', con=engine, if_exists='replace', chunksize = 100)

engine.execute("SELECT * FROM merged_data").fetchall()
# Out:
# [(0, 'Lee County', 'Alabama', 156597, 47564, 136953.0, 2.8793415187957283),
#  (1, 'Jefferson County', 'Alabama', 659460, 49321, 115941.0, 2.3507430911782),
#  (2, 'Marengo County', 'Alabama', 19743, 32255, 74335.0, 2.3046039373740506),
#  (3, 'Russell County', 'Alabama', 58480, 38988, 95871.0, 2.4589873807325335),
#  (4, 'Covington County', 'Alabama', 37519, 39467, 140630.0, 3.5632300402868218),
#  (5, 'Dallas County', 'Alabama', 40755, 30065, 115107.0, 3.828604689838683),
#  (6, 'Lauderdale County', 'Alabama', 92590, 44888, 100764.0, 2.244787025485653),
#  (7, 'Macon County', 'Alabama', 19358, 32308, 105436.0, 3.2634641574842145),
#  (8, 'Limestone County', 'Alabama', 91695, 52831, 91200.0, 1.726259203876512),
#  (9, 'Shelby County', 'Alabama', 208721, 74063, 112024.0, 1.5125501262438734),
#  (10, 'St. Clair County', 'Alabama', 86937, 53483, 147531.0, 2.7584653067329805),
#  (11, 'Baldwin County', 'Alabama', 203360, 52562, 99743.0, 1.8976256611240057),
# ...
